# %%
##Бонус-трек. Методы анализа данных. В этом ноутбуке будут представлены результаты выполнения индивидуальных заданий с 3 блока.

# %%
#Индивидуальное задание 3.1.1
#Задача 1.
#https://docs.google.com/spreadsheets/d/1csPlBXhsxJjS5CJeMfecdl85ue_G_lYtWSiyLZvQN1M/edit#gid=1786319303
#В предложенном файле находится набор синтетических данных. Данные описывают 60 объектов, каждый из которых обладает 10 признаками.
#Ваша задача, используя метод главных компонент, перейти к новым координатам и найти следующие параметры.

# %%
#1.1Введите координату первого объекта относительно первой главной компоненты.
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_excel("8_36-2.xls")

data.head(60)
# Out:
#            x0         x1         x2         x3         x4         x5  \
# 0  -21.268772   5.658494  15.694725 -21.573510  -0.105075  13.976255
# 1  -21.896195   3.149057  14.521728 -22.465232  -1.900296  12.834018
# 2  -20.993592   6.066762  15.965096 -23.837587  -3.383199  16.203912
# 3   19.398259  21.924278  17.982045   1.779974 -12.822293 -24.046872
# 4  -21.026319  23.054265 -19.370971 -10.060180 -19.241204 -15.206898
# 5  -22.450642  -9.693879  -5.095911  11.043118  21.141724  -5.555858
# 6  -14.855272   7.695260 -15.767561 -18.401784   1.249840 -18.819503
# 7  -23.989792  -7.493153  -4.840099  14.789728  22.788921 -10.501291
# 8  -23.969745  -6.834438  -8.642727  11.700804  21.936661  -7.113352
# 9  -17.588220   4.727917 -14.150823 -19.867924  -0.009068 -19.792233
# 10 -23.749772  22.437467 -19.279528  -9.065019 -20.646747 -13.516897
# 11   3.871252   2.085438  11.785910  11.042868   7.919648  -5.188986
# 12 -14.079746   8.288765 -14.531155 -18.558058  -0.758978 -19.686012
# ...

# %%
pca = PCA(n_components = 2, svd_solver = 'full').fit_transform(data) #Создание объекта класса PCA. В качестве параметров выступает количество ГК и метод оптимизации
pca.shape
# Out:
# (60, 2)

# %%
X_df = pd.DataFrame(pca, columns=['x', 'y'])
X_df
# Out:
#             x          y
# 0   33.152005 -22.021694
# 1   36.048587 -22.095488
# 2   36.147553 -25.344228
# 3  -25.090217 -25.511289
# 4   21.477431  12.806439
# 5  -16.134918  26.249383
# 6    4.633584  24.316734
# 7  -20.899990  28.087531
# 8  -18.029405  30.098264
# 9    8.428400  24.537935
# 10  20.836388  15.128891
# 11 -18.826689 -16.785477
# 12   7.594188  23.194279
# 13 -16.439544 -16.343121
# 14  20.060974  11.461039
# 15 -20.818620  29.276176
# 16  34.936097 -23.398350
# 17 -16.749956 -16.631701
# 18  35.495141 -20.405708
# 19  36.689257 -20.561240
# 20  20.614838  10.511861
# 21 -28.054044 -24.953046
# 22   6.639687  24.032063
# 23   1.472753  22.257256
# 24  19.733876  14.284405
# 25 -21.783018  27.090235
# 26  23.314545  13.460710
# 27 -29.133280 -22.309701
# 28 -25.548266 -25.160616
# 29   5.039050  21.782115
# 30 -14.078781 -15.447499
# 31 -21.840701 -25.506551
# 32 -19.899662  24.141495
# 33 -16.551301 -15.500870
# 34  32.915405 -21.249141
# 35 -17.795409 -18.829861
# ...

# %%
pca[0]
# Out:
# array([ 33.15200528, -22.02169371])

# %%
plt.scatter(pca[:61, 0], pca[:61, 1], edgecolor='none', s=40,cmap='winter')
# Out:
# <ipython-input-8-736f7745615b>:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(pca[:61, 0], pca[:61, 1], edgecolor='none', s=40,cmap='winter')

# %%
x_plot = X_df['x'].to_list()
y_plot = X_df['y'].to_list() #выше пример аналогичного по функции кода, который был дан в одном из примеров. Впрочем, видно, что разницы как таковой нет

# %%
plt.scatter(x_plot, y_plot)
plt.show()

# %%
pca = PCA(n_components=10, svd_solver='full')
X_full = pca.fit(data).transform(data)
X_full.shape
# Out:
# (60, 10)

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.27340385, 0.26172361, 0.25090029, 0.11048564, 0.09737171,
#        0.00186891, 0.00145442, 0.00112073, 0.00090387, 0.00076697])

# %%
x = 0
for i in range(3):
  x += explained_variance[i]
x  ##здесь я ищу, с какого момента доля объясненной дисперсии больше 0.85. Вообще это лучше делать через функцию кумулятивной суммы numpy.cumsum()
# Out:
# 0.786027740297403

# %%
###Задача 2.
# https://drive.google.com/drive/u/0/folders/1NIxfeRRZxd_IabyoOX7ZSh0T6kHxcRl9
#X_reduced и X_loadings - наши датасеты, представленные в папке

# %%
###Для прохода на новогодний корпоратив в ИТМО при входе нужно отгадать «логотип мероприятия». Для получения изображения логотипа необходимо по первым десяти главным компонентам восстановить исходное изображение (в качестве пригласительных рассылались матрица счётов и матрица весов первых десяти ГК).

# %%
#Импорт библиотеки Numpy
import numpy as np
#Создание массивов Numpy на основе матриц счётов и весов
scores = np.genfromtxt('X_reduced_408.csv', delimiter=';')
loadings = np.genfromtxt('X_loadings_408.csv', delimiter=';')
#Найдем матрицу восстановленных данных как произведение матрицы счётов на транспонированную матрицу весов.

values = np.dot(scores,loadings.T)
#Создадим изображение на основе полученных значений при помощи библиотеки matplotlib

#Импорт библиотеки
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
#Создание изображения
plt.imshow(values, cmap='Greys_r')
